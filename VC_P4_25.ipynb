# %%
import cv2  
import math

# %%
import torch

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA disponible: {torch.cuda.is_available()}")
print(f"CUDA version en PyTorch: {torch.version.cuda}")
print(f"Número de GPUs: {torch.cuda.device_count()}")

if torch.cuda.is_available():
    print(f"GPU detectada: {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch version: 2.6.0+cu124
# CUDA disponible: True
# CUDA version en PyTorch: 12.4
# Número de GPUs: 1
# GPU detectada: NVIDIA GeForce RTX 3050 Laptop GPU

# %%
from ultralytics import YOLO

model = YOLO('yolo11n.pt')

model.train(
    data="spanish-license-plates.v3i.yolov11/data.yaml",
    epochs=100,
    patience=10,
    batch=16,
    device='cuda',
    imgsz=640
)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from ultralytics import YOLO
#       3 model = YOLO('yolo11n.pt')
#       5 model.train(
#       6     data="spanish-license-plates.v3i.yolov11/data.yaml",
#       7     epochs=100,
#    (...)
#      11     imgsz=640
#      12 )
#
# File c:\Users\User\.conda\envs\VC_P4\lib\site-packages\ultralytics\__init__.py:13
#      10 if not os.environ.get("OMP_NUM_THREADS"):
#      11     os.environ["OMP_NUM_THREADS"] = "1"  # default for reduced CPU utilization during training
# ---> 13 from ultralytics.utils import ASSETS, SETTINGS
#      14 from ultralytics.utils.checks import check_yolo as checks
#      15 from ultralytics.utils.downloads import download
#
# File c:\Users\User\.conda\envs\VC_P4\lib\site-packages\ultralytics\utils\__init__.py:25
#      23 import cv2
#      24 import numpy as np
# ---> 25 import torch
#      27 from ultralytics import __version__
#      28 from ultralytics.utils.git import GitRepo
#
# File c:\Users\User\.conda\envs\VC_P4\lib\site-packages\torch\__init__.py:129
#     127     err = ctypes.WinError(last_error)
#     128     err.strerror += f' Error loading "{dll}" or one of its dependencies.'
# --> 129     raise err
#     130 elif res is not None:
#     131     is_loaded = True
#
# OSError: [WinError 182] El sistema operativo no puede ejecutar %1. Error loading "c:\Users\User\.conda\envs\VC_P4\lib\site-packages\torch\lib\shm.dll" or one of its dependencies.

# %%
# Validar el modelo entrenado
metrics = model.val()

# Validar un modelo guardado específico
# model = YOLO('runs/detect/train/weights/best.pt')
# metrics = model.val()

# %%
from ultralytics import YOLO

# Cargar el modelo entrenado
model = YOLO('runs/detect/train/weights/best.pt')

# Ejecutar validación
metrics = model.val()

# Mostrar métricas principales
print(f"mAP50-95: {metrics.box.map:.4f}")
print(f"mAP50: {metrics.box.map50:.4f}")
print(f"mAP75: {metrics.box.map75:.4f}")

# Precision, Recall y F1 por clase
print(f"\nPrecision (media): {metrics.box.mp:.4f}")
print(f"Recall (media): {metrics.box.mr:.4f}")

# F1 Score (calculado manualmente)
precision = metrics.box.mp
recall = metrics.box.mr
f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
print(f"F1 Score: {f1_score:.4f}")

# Métricas por cada clase
print("\nMétricas por clase:")
for i, map_value in enumerate(metrics.box.maps):
    print(f"Clase {i}: mAP50-95 = {map_value:.4f}")
