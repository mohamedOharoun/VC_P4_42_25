# %%
import cv2
import time
import pandas as pd
from collections import defaultdict
from ultralytics import YOLO

# Parámetros y rutas
VIDEOPATH = 'plates_test.MP4'
OUTPUTVIDEO = 'resultado.mp4'
OUTPUTCSV = 'detecciones.csv'

# Carga modelos
print("Cargando modelos...")
model_objects = YOLO("yolo11s.pt")       # Modelo para personas y vehículos
model_plates = YOLO("yolov11s_best.pt")   # Modelo matrícula

# Definiciones
VEHICLE_CLASSES = [2, 3, 5, 7]  # Clases vehículo (car, bus, etc)
PERSON_CLASS = 0
ALL_CLASSES = VEHICLE_CLASSES + [PERSON_CLASS]

class_counts = defaultdict(set)
detections_data = []
plate_cache = {}  # Almacena: {track_id: (matricula_info, last_frame_num, bbox)}

def detect_plate_in_vehicle_frame(frame, vehicle_box, frame_num):
    x1, y1, x2, y2 = map(int, vehicle_box)
    # Recorte vehículo + validación límites
    h, w = frame.shape[:2]
    x1, y1 = max(0, x1), max(0, y1)
    x2, y2 = min(w, x2), min(h, y2)
    if x2 <= x1 or y2 <= y1:
        return None
    vehicle_crop = frame[y1:y2, x1:x2]
    if vehicle_crop.size == 0:
        return None
    
    # Detección placa en recorte vehículo
    plate_results = model_plates(vehicle_crop, conf=0.4, imgsz=320, verbose=False)
    if len(plate_results[0].boxes) == 0:
        return None
    
    # Mejor caja por confianza
    best_idx = plate_results[0].boxes.conf.argmax()
    plate_box = plate_results[0].boxes[best_idx]
    px1, py1, px2, py2 = map(int, plate_box.xyxy[0])
    coords = (x1 + px1, y1 + py1, x1 + px2, y1 + py2)
    conf = float(plate_box.conf[0])
    
    # Texto OCR nominal (sólo demo, sustituir por OCR real si se tiene)
    plate_text = "MATRICULA"  # Aquí se puede integrar OCR real
    
    return {'coords': coords, 'conf': conf, 'text': plate_text, 'frame': frame_num}

def rectangles_iou(boxA, boxB):
    # Calcula el IoU entre 2 cajas: boxA y boxB = (x1,y1,x2,y2)
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])
    interArea = max(0, xB - xA) * max(0, yB - yA)
    boxAArea = (boxA[2] - boxA[0]) * (boxA[3] - boxA[1])
    boxBArea = (boxB[2] - boxB[0]) * (boxB[3] - boxB[1])
    iou = interArea / float(boxAArea + boxBArea - interArea) if (boxAArea + boxBArea - interArea) > 0 else 0
    return iou

def reidentify_track(new_box, new_plate_info, frame_num, max_iou=0.5, max_frame_gap=30):
    # Intentar encontrar un track_id anterior para la nueva detección usando matrícula y posición.
    for tid, (cached_plate, last_frame, cached_box) in plate_cache.items():
        if frame_num - last_frame > max_frame_gap:
            continue  # Muy viejo, descartar
        
        # Comparar matrícula si existe
        if new_plate_info and cached_plate:
            if new_plate_info['text'] == cached_plate['text']:
                # Matricula coincide: es el mismo objeto (vehículo)
                return tid
        
        # Sin matrícula o no coincide, comparar bounding boxes (IoU)
        iou = rectangles_iou(new_box, cached_box)
        if iou > max_iou:
            return tid  # Es el mismo objeto con movimiento razonable
    
    return None  # No encontrado

# Abre vídeo y prepara salida
cap = cv2.VideoCapture(VIDEOPATH)
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

out = cv2.VideoWriter(OUTPUTVIDEO, cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))

frame_idx = 0
start_time = time.time()

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    
    results = model_objects.track(frame, persist=True, conf=0.4, classes=ALL_CLASSES, imgsz=640)
    
    if results[0].boxes is not None and len(results[0].boxes) > 0:
        boxes = results[0].boxes.xyxy.cpu().numpy()
        classes = results[0].boxes.cls.cpu().numpy().astype(int)
        confs = results[0].boxes.conf.cpu().numpy()
        track_ids = results[0].boxes.id.cpu().numpy().astype(int) if results[0].boxes.id is not None else range(len(boxes))
        
        for box, cls, conf, tid in zip(boxes, classes, confs, track_ids):
            x1, y1, x2, y2 = map(int, box)
            obj_type = model_objects.names[cls]
            
            plate_info = None
            
            if cls in VEHICLE_CLASSES:
                if frame_idx % 5 == 0:
                    plate_info = detect_plate_in_vehicle_frame(frame, box, frame_idx)
                
                if not plate_info and tid in plate_cache:
                    plate_info = plate_cache[tid][0]
                
                if plate_info:
                    reid_id = reidentify_track(box, plate_info, frame_idx)
                    if reid_id is not None and reid_id != tid:
                        tid = reid_id
                
                plate_cache[tid] = (plate_info, frame_idx, box)
            
            class_counts[obj_type].add(tid)
            
            detections_data.append({
                'fotograma': frame_idx,
                'tipo_objeto': obj_type,
                'confianza': round(float(conf), 3),
                'identificador_tracking': int(tid),
                'x1': x1, 'y1': y1, 'x2': x2, 'y2': y2,
                'matricula_en_su_caso': plate_info['text'] if plate_info else '',
                'confianza_matricula': round(plate_info['conf'], 3) if plate_info else 0.0,
                'mx1': plate_info['coords'][0] if plate_info else 0,
                'my1': plate_info['coords'][1] if plate_info else 0,
                'mx2': plate_info['coords'][2] if plate_info else 0,
                'my2': plate_info['coords'][3] if plate_info else 0,
                'texto_matricula': plate_info['text'] if plate_info else ''
            })
            
            color = (0, 255, 0) if cls == PERSON_CLASS else (255, 0, 0)
            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            
            info_text = f"ID{tid} {obj_type} {conf:.2f}"
            text_size = cv2.getTextSize(info_text, cv2.FONT_HERSHEY_SIMPLEX, 0.55, 2)[0]
            text_x, text_y = x1, max(y1 - 12, text_size[1])
            cv2.rectangle(frame, (text_x, text_y - text_size[1] - 2), (text_x + text_size[0], text_y + 2), (0, 0, 0), -1)
            cv2.putText(frame, info_text, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 0.55, color, 2)
            
            if plate_info:
                px1, py1, px2, py2 = plate_info['coords']
                cv2.rectangle(frame, (px1, py1), (px2, py2), (0, 255, 255), 2)
                plate_text = f"Plate {plate_info['conf']:.2f}"
                ptext_size = cv2.getTextSize(plate_text, cv2.FONT_HERSHEY_SIMPLEX, 0.5, 2)[0]
                ptext_x, ptext_y = px1, max(py1 - 8, ptext_size[1])
                cv2.rectangle(frame, (ptext_x, ptext_y - ptext_size[1] - 2), (ptext_x + ptext_size[0], ptext_y + 2), (0, 0, 0), -1)
                cv2.putText(frame, plate_text, (ptext_x, ptext_y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 255), 2)

    y = 30
    for obj, ids in class_counts.items():
        cv2.putText(frame, f"{obj}: {len(ids)}", (10, y), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)
        y += 30
    
    out.write(frame)
    frame_idx += 1

    if frame_idx % 30 == 0:
        frames_left = total_frames - frame_idx
        print(f"Frame {frame_idx}/{total_frames} - Quedan {frames_left} frames")

cap.release()
out.release()

df = pd.DataFrame(detections_data)
df.to_csv(OUTPUTCSV, index=False)

print("="*60)
print("Proceso completado")
print(f"Objetos únicos detectados:")
for obj, ids in class_counts.items():
    print(f"{obj}: {len(ids)}")

print(f"Matrículas detectadas: {len(plate_cache)}")
print("="*60)
# Out:
# Cargando modelos...
#
# 0: 384x640 3 cars, 1 bus, 230.0ms
# Speed: 9.2ms preprocess, 230.0ms inference, 50.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 26.5ms
# Speed: 3.9ms preprocess, 26.5ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 25.2ms
# Speed: 4.0ms preprocess, 25.2ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 18.9ms
# Speed: 3.0ms preprocess, 18.9ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 19.6ms
# Speed: 3.5ms preprocess, 19.6ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 20.3ms
# Speed: 3.1ms preprocess, 20.3ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 22.9ms
# Speed: 3.0ms preprocess, 22.9ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 20.1ms
# Speed: 3.7ms preprocess, 20.1ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 25.1ms
# Speed: 3.3ms preprocess, 25.1ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 19.8ms
# Speed: 3.2ms preprocess, 19.8ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 19.1ms
# Speed: 3.9ms preprocess, 19.1ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 21.5ms
# Speed: 3.1ms preprocess, 21.5ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 19.6ms
# Speed: 3.0ms preprocess, 19.6ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 21.6ms
# Speed: 2.9ms preprocess, 21.6ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 19.9ms
# Speed: 2.9ms preprocess, 19.9ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 19.3ms
# Speed: 3.5ms preprocess, 19.3ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 23.0ms
# Speed: 3.2ms preprocess, 23.0ms inference, 16.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 20.2ms
# Speed: 3.1ms preprocess, 20.2ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 18.7ms
# Speed: 3.6ms preprocess, 18.7ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 22.4ms
# Speed: 3.0ms preprocess, 22.4ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 24.7ms
# Speed: 3.0ms preprocess, 24.7ms inference, 10.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 27.6ms
# Speed: 3.6ms preprocess, 27.6ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 37.3ms
# Speed: 4.0ms preprocess, 37.3ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 33.0ms
# Speed: 3.6ms preprocess, 33.0ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 29.4ms
# Speed: 3.4ms preprocess, 29.4ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 29.2ms
# Speed: 4.1ms preprocess, 29.2ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 36.7ms
# Speed: 3.7ms preprocess, 36.7ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 23.5ms
# Speed: 3.8ms preprocess, 23.5ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 20.0ms
# Speed: 3.4ms preprocess, 20.0ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 21.3ms
# Speed: 3.2ms preprocess, 21.3ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 30/2832 - Quedan 2802 frames
#
# 0: 384x640 1 person, 2 cars, 1 bus, 18.0ms
# Speed: 3.4ms preprocess, 18.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 36.0ms
# Speed: 4.2ms preprocess, 36.0ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 36.1ms
# Speed: 4.1ms preprocess, 36.1ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 36.3ms
# Speed: 4.0ms preprocess, 36.3ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 36.6ms
# Speed: 4.1ms preprocess, 36.6ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 38.8ms
# Speed: 5.0ms preprocess, 38.8ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 37.0ms
# Speed: 4.9ms preprocess, 37.0ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 36.8ms
# Speed: 3.7ms preprocess, 36.8ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 36.9ms
# Speed: 4.4ms preprocess, 36.9ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 36.7ms
# Speed: 4.1ms preprocess, 36.7ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 36.8ms
# Speed: 4.8ms preprocess, 36.8ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 36.6ms
# Speed: 5.5ms preprocess, 36.6ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 36.9ms
# Speed: 4.5ms preprocess, 36.9ms inference, 11.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 36.9ms
# Speed: 4.1ms preprocess, 36.9ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 36.7ms
# Speed: 4.0ms preprocess, 36.7ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 36.7ms
# Speed: 4.1ms preprocess, 36.7ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 36.8ms
# Speed: 4.2ms preprocess, 36.8ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 38.1ms
# Speed: 4.0ms preprocess, 38.1ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 56.9ms
# Speed: 4.2ms preprocess, 56.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 73.4ms
# Speed: 5.5ms preprocess, 73.4ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 69.2ms
# Speed: 5.0ms preprocess, 69.2ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 36.8ms
# Speed: 4.5ms preprocess, 36.8ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 36.7ms
# Speed: 5.0ms preprocess, 36.7ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 36.8ms
# Speed: 4.3ms preprocess, 36.8ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 36.7ms
# Speed: 3.9ms preprocess, 36.7ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 36.8ms
# Speed: 4.0ms preprocess, 36.8ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 36.7ms
# Speed: 4.3ms preprocess, 36.7ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 37.0ms
# Speed: 4.8ms preprocess, 37.0ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 36.7ms
# Speed: 4.4ms preprocess, 36.7ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 37.0ms
# Speed: 4.4ms preprocess, 37.0ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 60/2832 - Quedan 2772 frames
#
# 0: 384x640 1 bus, 37.1ms
# Speed: 4.4ms preprocess, 37.1ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 36.8ms
# Speed: 4.6ms preprocess, 36.8ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 72.6ms
# Speed: 5.0ms preprocess, 72.6ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 72.6ms
# Speed: 5.8ms preprocess, 72.6ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 72.6ms
# Speed: 5.4ms preprocess, 72.6ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 72.8ms
# Speed: 5.8ms preprocess, 72.8ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 72.8ms
# Speed: 4.9ms preprocess, 72.8ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 21.1ms
# Speed: 3.3ms preprocess, 21.1ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 31.3ms
# Speed: 3.3ms preprocess, 31.3ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 28.6ms
# Speed: 4.0ms preprocess, 28.6ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 21.8ms
# Speed: 3.3ms preprocess, 21.8ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 22.2ms
# Speed: 3.5ms preprocess, 22.2ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 21.7ms
# Speed: 3.7ms preprocess, 21.7ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 24.6ms
# Speed: 3.8ms preprocess, 24.6ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 23.0ms
# Speed: 3.2ms preprocess, 23.0ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 23.7ms
# Speed: 3.7ms preprocess, 23.7ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 25.9ms
# Speed: 3.4ms preprocess, 25.9ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 29.4ms
# Speed: 3.8ms preprocess, 29.4ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 24.7ms
# Speed: 3.8ms preprocess, 24.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 20.5ms
# Speed: 3.7ms preprocess, 20.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 30.4ms
# Speed: 3.9ms preprocess, 30.4ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 36.0ms
# Speed: 3.3ms preprocess, 36.0ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 24.7ms
# Speed: 4.6ms preprocess, 24.7ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 22.2ms
# Speed: 3.5ms preprocess, 22.2ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 22.8ms
# Speed: 3.6ms preprocess, 22.8ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 26.7ms
# Speed: 4.1ms preprocess, 26.7ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 24.1ms
# Speed: 3.5ms preprocess, 24.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 24.3ms
# Speed: 3.4ms preprocess, 24.3ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 24.7ms
# Speed: 4.1ms preprocess, 24.7ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 25.4ms
# Speed: 3.4ms preprocess, 25.4ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# Frame 90/2832 - Quedan 2742 frames
#
# 0: 384x640 2 cars, 1 bus, 41.2ms
# Speed: 4.0ms preprocess, 41.2ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 41.1ms
# Speed: 5.9ms preprocess, 41.1ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 41.2ms
# Speed: 4.3ms preprocess, 41.2ms inference, 11.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 41.1ms
# Speed: 4.2ms preprocess, 41.1ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 41.2ms
# Speed: 4.2ms preprocess, 41.2ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 41.3ms
# Speed: 4.4ms preprocess, 41.3ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 41.3ms
# Speed: 4.4ms preprocess, 41.3ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 38.4ms
# Speed: 4.2ms preprocess, 38.4ms inference, 10.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 38.7ms
# Speed: 6.2ms preprocess, 38.7ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 38.4ms
# Speed: 4.1ms preprocess, 38.4ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 38.3ms
# Speed: 4.5ms preprocess, 38.3ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 38.3ms
# Speed: 4.2ms preprocess, 38.3ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 38.2ms
# Speed: 4.6ms preprocess, 38.2ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 38.2ms
# Speed: 4.3ms preprocess, 38.2ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 38.1ms
# Speed: 4.2ms preprocess, 38.1ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 38.1ms
# Speed: 3.8ms preprocess, 38.1ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 38.0ms
# Speed: 5.1ms preprocess, 38.0ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 truck, 36.2ms
# Speed: 4.3ms preprocess, 36.2ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 36.5ms
# Speed: 4.3ms preprocess, 36.5ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 36.4ms
# Speed: 4.3ms preprocess, 36.4ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 36.5ms
# Speed: 4.6ms preprocess, 36.5ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 36.6ms
# Speed: 4.3ms preprocess, 36.6ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 37.0ms
# Speed: 4.9ms preprocess, 37.0ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 37.0ms
# Speed: 4.5ms preprocess, 37.0ms inference, 14.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 37.0ms
# Speed: 4.0ms preprocess, 37.0ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 37.0ms
# Speed: 4.4ms preprocess, 37.0ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 36.9ms
# Speed: 4.6ms preprocess, 36.9ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 37.0ms
# Speed: 4.1ms preprocess, 37.0ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 72.3ms
# Speed: 5.3ms preprocess, 72.3ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 72.2ms
# Speed: 5.7ms preprocess, 72.2ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 120/2832 - Quedan 2712 frames
#
# 0: 384x640 1 person, 1 car, 1 bus, 72.4ms
# Speed: 5.4ms preprocess, 72.4ms inference, 16.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 72.0ms
# Speed: 5.7ms preprocess, 72.0ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 34.2ms
# Speed: 4.8ms preprocess, 34.2ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 34.2ms
# Speed: 4.6ms preprocess, 34.2ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 34.2ms
# Speed: 4.2ms preprocess, 34.2ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 34.1ms
# Speed: 4.5ms preprocess, 34.1ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 34.2ms
# Speed: 4.5ms preprocess, 34.2ms inference, 14.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 34.2ms
# Speed: 4.1ms preprocess, 34.2ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 34.2ms
# Speed: 4.2ms preprocess, 34.2ms inference, 10.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 truck, 34.0ms
# Speed: 4.6ms preprocess, 34.0ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 truck, 34.0ms
# Speed: 3.9ms preprocess, 34.0ms inference, 15.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 truck, 34.4ms
# Speed: 4.8ms preprocess, 34.4ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 34.7ms
# Speed: 4.1ms preprocess, 34.7ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 34.8ms
# Speed: 4.2ms preprocess, 34.8ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 35.0ms
# Speed: 4.7ms preprocess, 35.0ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 34.9ms
# Speed: 4.0ms preprocess, 34.9ms inference, 11.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 35.3ms
# Speed: 4.6ms preprocess, 35.3ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 35.0ms
# Speed: 4.3ms preprocess, 35.0ms inference, 14.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 34.9ms
# Speed: 4.5ms preprocess, 34.9ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 34.8ms
# Speed: 4.0ms preprocess, 34.8ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 34.8ms
# Speed: 4.4ms preprocess, 34.8ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 35.0ms
# Speed: 4.2ms preprocess, 35.0ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 34.6ms
# Speed: 4.5ms preprocess, 34.6ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 35.3ms
# Speed: 6.7ms preprocess, 35.3ms inference, 14.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 34.8ms
# Speed: 4.2ms preprocess, 34.8ms inference, 16.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 truck, 34.8ms
# Speed: 3.9ms preprocess, 34.8ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 truck, 34.8ms
# Speed: 4.6ms preprocess, 34.8ms inference, 12.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 truck, 34.7ms
# Speed: 4.3ms preprocess, 34.7ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 truck, 34.7ms
# Speed: 4.6ms preprocess, 34.7ms inference, 17.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 truck, 34.9ms
# Speed: 4.6ms preprocess, 34.9ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 150/2832 - Quedan 2682 frames
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 truck, 35.0ms
# Speed: 4.0ms preprocess, 35.0ms inference, 18.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 truck, 34.7ms
# Speed: 4.8ms preprocess, 34.7ms inference, 18.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 1 truck, 34.9ms
# Speed: 4.8ms preprocess, 34.9ms inference, 9.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 35.0ms
# Speed: 4.3ms preprocess, 35.0ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 34.8ms
# Speed: 4.4ms preprocess, 34.8ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 34.7ms
# Speed: 4.5ms preprocess, 34.7ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 34.7ms
# Speed: 4.3ms preprocess, 34.7ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 34.6ms
# Speed: 4.5ms preprocess, 34.6ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 34.5ms
# Speed: 4.5ms preprocess, 34.5ms inference, 15.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 34.5ms
# Speed: 4.5ms preprocess, 34.5ms inference, 13.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 34.8ms
# Speed: 4.6ms preprocess, 34.8ms inference, 14.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 34.9ms
# Speed: 4.5ms preprocess, 34.9ms inference, 14.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 34.3ms
# Speed: 4.1ms preprocess, 34.3ms inference, 17.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 34.2ms
# Speed: 4.3ms preprocess, 34.2ms inference, 17.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 34.5ms
# Speed: 4.4ms preprocess, 34.5ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 34.4ms
# Speed: 3.9ms preprocess, 34.4ms inference, 16.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 34.4ms
# Speed: 4.6ms preprocess, 34.4ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 34.1ms
# Speed: 4.5ms preprocess, 34.1ms inference, 13.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 34.1ms
# Speed: 4.5ms preprocess, 34.1ms inference, 15.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 34.5ms
# Speed: 4.3ms preprocess, 34.5ms inference, 17.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 34.3ms
# Speed: 3.9ms preprocess, 34.3ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 34.4ms
# Speed: 4.7ms preprocess, 34.4ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 34.9ms
# Speed: 4.4ms preprocess, 34.9ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 35.0ms
# Speed: 4.6ms preprocess, 35.0ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 35.0ms
# Speed: 4.2ms preprocess, 35.0ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 35.4ms
# Speed: 18.0ms preprocess, 35.4ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 35.6ms
# Speed: 4.7ms preprocess, 35.6ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 34.7ms
# Speed: 4.6ms preprocess, 34.7ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 34.9ms
# Speed: 3.9ms preprocess, 34.9ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 34.8ms
# Speed: 4.5ms preprocess, 34.8ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 180/2832 - Quedan 2652 frames
#
# 0: 384x640 1 person, 3 cars, 1 bus, 35.0ms
# Speed: 4.8ms preprocess, 35.0ms inference, 11.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 34.9ms
# Speed: 4.3ms preprocess, 34.9ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 34.0ms
# Speed: 4.3ms preprocess, 34.0ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 33.9ms
# Speed: 4.0ms preprocess, 33.9ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 34.1ms
# Speed: 4.7ms preprocess, 34.1ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 33.8ms
# Speed: 4.3ms preprocess, 33.8ms inference, 13.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 34.0ms
# Speed: 4.1ms preprocess, 34.0ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 34.1ms
# Speed: 4.6ms preprocess, 34.1ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 34.5ms
# Speed: 4.6ms preprocess, 34.5ms inference, 15.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 34.2ms
# Speed: 4.4ms preprocess, 34.2ms inference, 15.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 36.0ms
# Speed: 4.5ms preprocess, 36.0ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 34.0ms
# Speed: 4.6ms preprocess, 34.0ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 33.9ms
# Speed: 4.8ms preprocess, 33.9ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 34.5ms
# Speed: 4.2ms preprocess, 34.5ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 35.0ms
# Speed: 4.3ms preprocess, 35.0ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 34.9ms
# Speed: 4.6ms preprocess, 34.9ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 35.0ms
# Speed: 4.1ms preprocess, 35.0ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 34.9ms
# Speed: 3.9ms preprocess, 34.9ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 35.3ms
# Speed: 4.5ms preprocess, 35.3ms inference, 10.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 35.3ms
# Speed: 4.6ms preprocess, 35.3ms inference, 10.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 35.3ms
# Speed: 4.5ms preprocess, 35.3ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 35.4ms
# Speed: 4.4ms preprocess, 35.4ms inference, 16.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 35.6ms
# Speed: 4.4ms preprocess, 35.6ms inference, 10.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 35.8ms
# Speed: 4.9ms preprocess, 35.8ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 36.1ms
# Speed: 4.5ms preprocess, 36.1ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 36.1ms
# Speed: 4.8ms preprocess, 36.1ms inference, 11.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 36.2ms
# Speed: 4.3ms preprocess, 36.2ms inference, 18.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 36.3ms
# Speed: 4.9ms preprocess, 36.3ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 36.2ms
# Speed: 4.9ms preprocess, 36.2ms inference, 10.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 36.2ms
# Speed: 5.0ms preprocess, 36.2ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 210/2832 - Quedan 2622 frames
#
# 0: 384x640 1 person, 3 cars, 1 bus, 36.3ms
# Speed: 4.8ms preprocess, 36.3ms inference, 18.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 36.2ms
# Speed: 4.3ms preprocess, 36.2ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 35.8ms
# Speed: 4.7ms preprocess, 35.8ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 35.8ms
# Speed: 4.6ms preprocess, 35.8ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 35.6ms
# Speed: 4.5ms preprocess, 35.6ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 35.5ms
# Speed: 4.3ms preprocess, 35.5ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 35.7ms
# Speed: 4.2ms preprocess, 35.7ms inference, 10.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 35.6ms
# Speed: 4.7ms preprocess, 35.6ms inference, 17.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 35.7ms
# Speed: 4.4ms preprocess, 35.7ms inference, 18.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 35.6ms
# Speed: 4.3ms preprocess, 35.6ms inference, 11.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 35.5ms
# Speed: 4.2ms preprocess, 35.5ms inference, 11.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 35.2ms
# Speed: 4.2ms preprocess, 35.2ms inference, 17.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 35.0ms
# Speed: 4.6ms preprocess, 35.0ms inference, 25.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 35.5ms
# Speed: 4.5ms preprocess, 35.5ms inference, 11.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 35.3ms
# Speed: 4.9ms preprocess, 35.3ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 35.0ms
# Speed: 4.6ms preprocess, 35.0ms inference, 14.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 34.9ms
# Speed: 3.9ms preprocess, 34.9ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 34.9ms
# Speed: 4.5ms preprocess, 34.9ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 35.0ms
# Speed: 4.7ms preprocess, 35.0ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 34.8ms
# Speed: 4.2ms preprocess, 34.8ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 35.1ms
# Speed: 4.3ms preprocess, 35.1ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 35.5ms
# Speed: 4.1ms preprocess, 35.5ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 35.1ms
# Speed: 4.7ms preprocess, 35.1ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 35.1ms
# Speed: 4.1ms preprocess, 35.1ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 truck, 35.1ms
# Speed: 3.9ms preprocess, 35.1ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 truck, 35.0ms
# Speed: 4.5ms preprocess, 35.0ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 truck, 35.1ms
# Speed: 4.1ms preprocess, 35.1ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 1 truck, 35.1ms
# Speed: 4.2ms preprocess, 35.1ms inference, 10.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 1 truck, 35.3ms
# Speed: 4.8ms preprocess, 35.3ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 truck, 35.2ms
# Speed: 4.7ms preprocess, 35.2ms inference, 21.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 240/2832 - Quedan 2592 frames
#
# 0: 384x640 1 person, 4 cars, 1 truck, 35.0ms
# Speed: 4.7ms preprocess, 35.0ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 truck, 35.2ms
# Speed: 4.2ms preprocess, 35.2ms inference, 16.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 35.5ms
# Speed: 5.1ms preprocess, 35.5ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 35.7ms
# Speed: 4.8ms preprocess, 35.7ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 35.6ms
# Speed: 4.4ms preprocess, 35.6ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 35.8ms
# Speed: 4.4ms preprocess, 35.8ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 35.4ms
# Speed: 4.3ms preprocess, 35.4ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 35.1ms
# Speed: 4.7ms preprocess, 35.1ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 35.1ms
# Speed: 4.4ms preprocess, 35.1ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 35.5ms
# Speed: 4.5ms preprocess, 35.5ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 35.1ms
# Speed: 4.9ms preprocess, 35.1ms inference, 15.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 35.1ms
# Speed: 4.5ms preprocess, 35.1ms inference, 18.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 35.1ms
# Speed: 4.8ms preprocess, 35.1ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 35.1ms
# Speed: 4.5ms preprocess, 35.1ms inference, 10.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 35.1ms
# Speed: 4.7ms preprocess, 35.1ms inference, 10.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 35.1ms
# Speed: 4.6ms preprocess, 35.1ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 35.0ms
# Speed: 4.5ms preprocess, 35.0ms inference, 9.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 33.8ms
# Speed: 4.9ms preprocess, 33.8ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 33.9ms
# Speed: 4.4ms preprocess, 33.9ms inference, 12.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 33.8ms
# Speed: 4.0ms preprocess, 33.8ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 33.8ms
# Speed: 4.9ms preprocess, 33.8ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 33.8ms
# Speed: 4.0ms preprocess, 33.8ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 34.1ms
# Speed: 4.6ms preprocess, 34.1ms inference, 10.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 33.9ms
# Speed: 4.1ms preprocess, 33.9ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 33.8ms
# Speed: 4.5ms preprocess, 33.8ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 33.7ms
# Speed: 4.1ms preprocess, 33.7ms inference, 13.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 34.9ms
# Speed: 4.4ms preprocess, 34.9ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 35.1ms
# Speed: 4.7ms preprocess, 35.1ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 35.1ms
# Speed: 4.6ms preprocess, 35.1ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 34.9ms
# Speed: 4.0ms preprocess, 34.9ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
# Frame 270/2832 - Quedan 2562 frames
#
# 0: 384x640 1 person, 4 cars, 1 bus, 35.1ms
# Speed: 4.8ms preprocess, 35.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 34.9ms
# Speed: 4.3ms preprocess, 34.9ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 34.6ms
# Speed: 4.7ms preprocess, 34.6ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 34.6ms
# Speed: 4.3ms preprocess, 34.6ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 34.8ms
# Speed: 4.0ms preprocess, 34.8ms inference, 12.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 34.9ms
# Speed: 4.1ms preprocess, 34.9ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 1 bus, 34.6ms
# Speed: 4.7ms preprocess, 34.6ms inference, 11.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 33.9ms
# Speed: 4.4ms preprocess, 33.9ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 33.9ms
# Speed: 4.4ms preprocess, 33.9ms inference, 13.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 34.1ms
# Speed: 4.1ms preprocess, 34.1ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 34.0ms
# Speed: 4.1ms preprocess, 34.0ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 1 truck, 33.9ms
# Speed: 4.2ms preprocess, 33.9ms inference, 10.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 1 truck, 34.0ms
# Speed: 4.0ms preprocess, 34.0ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 1 truck, 33.9ms
# Speed: 4.2ms preprocess, 33.9ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 1 truck, 34.1ms
# Speed: 4.0ms preprocess, 34.1ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 1 truck, 33.8ms
# Speed: 4.0ms preprocess, 33.8ms inference, 10.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 1 truck, 33.2ms
# Speed: 4.2ms preprocess, 33.2ms inference, 11.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 1 truck, 33.3ms
# Speed: 4.1ms preprocess, 33.3ms inference, 11.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 33.4ms
# Speed: 4.2ms preprocess, 33.4ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 33.4ms
# Speed: 4.2ms preprocess, 33.4ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 33.5ms
# Speed: 4.6ms preprocess, 33.5ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 33.3ms
# Speed: 4.1ms preprocess, 33.3ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 33.2ms
# Speed: 4.7ms preprocess, 33.2ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 33.6ms
# Speed: 4.3ms preprocess, 33.6ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 33.5ms
# Speed: 4.4ms preprocess, 33.5ms inference, 11.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 33.3ms
# Speed: 4.2ms preprocess, 33.3ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 33.2ms
# Speed: 4.3ms preprocess, 33.2ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 33.6ms
# Speed: 4.4ms preprocess, 33.6ms inference, 10.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 34.1ms
# Speed: 5.8ms preprocess, 34.1ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 33.9ms
# Speed: 4.2ms preprocess, 33.9ms inference, 11.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 300/2832 - Quedan 2532 frames
#
# 0: 384x640 2 persons, 4 cars, 33.8ms
# Speed: 4.0ms preprocess, 33.8ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 33.9ms
# Speed: 4.1ms preprocess, 33.9ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 33.1ms
# Speed: 4.1ms preprocess, 33.1ms inference, 10.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 33.2ms
# Speed: 4.6ms preprocess, 33.2ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 33.4ms
# Speed: 3.9ms preprocess, 33.4ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 33.3ms
# Speed: 4.6ms preprocess, 33.3ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 33.2ms
# Speed: 4.1ms preprocess, 33.2ms inference, 10.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 truck, 32.9ms
# Speed: 4.3ms preprocess, 32.9ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 truck, 33.0ms
# Speed: 4.2ms preprocess, 33.0ms inference, 12.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 truck, 33.1ms
# Speed: 4.2ms preprocess, 33.1ms inference, 11.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 truck, 33.2ms
# Speed: 4.6ms preprocess, 33.2ms inference, 18.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 truck, 32.7ms
# Speed: 4.5ms preprocess, 32.7ms inference, 11.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 33.2ms
# Speed: 4.3ms preprocess, 33.2ms inference, 9.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 truck, 32.7ms
# Speed: 4.2ms preprocess, 32.7ms inference, 11.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 truck, 33.2ms
# Speed: 4.1ms preprocess, 33.2ms inference, 12.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 bus, 32.8ms
# Speed: 4.3ms preprocess, 32.8ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 bus, 32.7ms
# Speed: 4.3ms preprocess, 32.7ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 bus, 33.1ms
# Speed: 4.4ms preprocess, 33.1ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 bus, 33.5ms
# Speed: 4.5ms preprocess, 33.5ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 bus, 33.5ms
# Speed: 4.5ms preprocess, 33.5ms inference, 10.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 bus, 33.4ms
# Speed: 4.8ms preprocess, 33.4ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 bus, 33.9ms
# Speed: 4.4ms preprocess, 33.9ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 21.7ms
# Speed: 4.1ms preprocess, 21.7ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 19.9ms
# Speed: 3.2ms preprocess, 19.9ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 23.1ms
# Speed: 3.3ms preprocess, 23.1ms inference, 11.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 22.6ms
# Speed: 3.5ms preprocess, 22.6ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 21.1ms
# Speed: 3.5ms preprocess, 21.1ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 20.9ms
# Speed: 3.5ms preprocess, 20.9ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 19.8ms
# Speed: 3.4ms preprocess, 19.8ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 20.6ms
# Speed: 3.6ms preprocess, 20.6ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 330/2832 - Quedan 2502 frames
#
# 0: 384x640 3 persons, 4 cars, 24.9ms
# Speed: 3.6ms preprocess, 24.9ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 22.9ms
# Speed: 3.1ms preprocess, 22.9ms inference, 11.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 21.9ms
# Speed: 3.7ms preprocess, 21.9ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 22.8ms
# Speed: 3.7ms preprocess, 22.8ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 35.9ms
# Speed: 4.6ms preprocess, 35.9ms inference, 10.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 36.3ms
# Speed: 4.1ms preprocess, 36.3ms inference, 10.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 36.6ms
# Speed: 4.1ms preprocess, 36.6ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 35.4ms
# Speed: 4.7ms preprocess, 35.4ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 35.5ms
# Speed: 4.2ms preprocess, 35.5ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 35.9ms
# Speed: 4.0ms preprocess, 35.9ms inference, 10.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 35.5ms
# Speed: 4.4ms preprocess, 35.5ms inference, 10.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 35.5ms
# Speed: 4.0ms preprocess, 35.5ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 34.9ms
# Speed: 4.3ms preprocess, 34.9ms inference, 10.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 4 cars, 34.7ms
# ...
#
# 0: 384x640 1 person, 5 cars, 34.2ms
# Speed: 4.1ms preprocess, 34.2ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 33.2ms
# Speed: 3.8ms preprocess, 33.2ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 33.1ms
# Speed: 4.0ms preprocess, 33.1ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 33.1ms
# Speed: 4.0ms preprocess, 33.1ms inference, 16.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 33.2ms
# Speed: 3.9ms preprocess, 33.2ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 33.2ms
# Speed: 3.8ms preprocess, 33.2ms inference, 17.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 36.2ms
# Speed: 6.6ms preprocess, 36.2ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 33.3ms
# Speed: 4.5ms preprocess, 33.3ms inference, 14.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 33.2ms
# Speed: 3.6ms preprocess, 33.2ms inference, 10.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 33.1ms
# Speed: 3.9ms preprocess, 33.1ms inference, 16.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 33.1ms
# Speed: 3.8ms preprocess, 33.1ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 33.4ms
# Speed: 4.0ms preprocess, 33.4ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 34.0ms
# Speed: 4.6ms preprocess, 34.0ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 34.2ms
# Speed: 4.2ms preprocess, 34.2ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 2730/2832 - Quedan 102 frames
#
# 0: 384x640 1 person, 3 cars, 34.3ms
# Speed: 4.7ms preprocess, 34.3ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 34.3ms
# Speed: 4.0ms preprocess, 34.3ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 34.4ms
# Speed: 4.1ms preprocess, 34.4ms inference, 16.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 34.9ms
# Speed: 3.8ms preprocess, 34.9ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 34.6ms
# Speed: 3.9ms preprocess, 34.6ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 34.8ms
# Speed: 4.0ms preprocess, 34.8ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 35.0ms
# Speed: 3.6ms preprocess, 35.0ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 35.0ms
# Speed: 3.8ms preprocess, 35.0ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 35.4ms
# Speed: 4.6ms preprocess, 35.4ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 35.2ms
# Speed: 3.8ms preprocess, 35.2ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 35.4ms
# Speed: 3.8ms preprocess, 35.4ms inference, 14.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 35.7ms
# Speed: 4.3ms preprocess, 35.7ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 35.3ms
# Speed: 4.1ms preprocess, 35.3ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 35.7ms
# Speed: 3.5ms preprocess, 35.7ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 35.9ms
# Speed: 4.4ms preprocess, 35.9ms inference, 17.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 35.9ms
# Speed: 4.0ms preprocess, 35.9ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 37.0ms
# Speed: 3.8ms preprocess, 37.0ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 36.0ms
# Speed: 4.8ms preprocess, 36.0ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 36.2ms
# Speed: 3.9ms preprocess, 36.2ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 36.7ms
# Speed: 3.9ms preprocess, 36.7ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 59.4ms
# Speed: 3.9ms preprocess, 59.4ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 34.3ms
# Speed: 4.0ms preprocess, 34.3ms inference, 12.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 34.4ms
# Speed: 4.4ms preprocess, 34.4ms inference, 17.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 34.9ms
# Speed: 4.5ms preprocess, 34.9ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 34.4ms
# Speed: 4.3ms preprocess, 34.4ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 34.4ms
# Speed: 3.8ms preprocess, 34.4ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 34.4ms
# Speed: 4.1ms preprocess, 34.4ms inference, 12.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 34.4ms
# Speed: 3.9ms preprocess, 34.4ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 34.6ms
# Speed: 4.3ms preprocess, 34.6ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 34.5ms
# Speed: 4.1ms preprocess, 34.5ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 2760/2832 - Quedan 72 frames
#
# 0: 384x640 1 person, 4 cars, 34.3ms
# Speed: 3.9ms preprocess, 34.3ms inference, 19.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 34.4ms
# Speed: 4.3ms preprocess, 34.4ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 34.0ms
# Speed: 4.1ms preprocess, 34.0ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 34.1ms
# Speed: 3.8ms preprocess, 34.1ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 34.5ms
# Speed: 3.8ms preprocess, 34.5ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 34.0ms
# Speed: 3.6ms preprocess, 34.0ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 34.1ms
# Speed: 3.8ms preprocess, 34.1ms inference, 10.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 37.8ms
# Speed: 3.9ms preprocess, 37.8ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 33.4ms
# Speed: 4.0ms preprocess, 33.4ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 33.4ms
# Speed: 6.1ms preprocess, 33.4ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 33.5ms
# Speed: 3.9ms preprocess, 33.5ms inference, 10.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 33.6ms
# Speed: 4.1ms preprocess, 33.6ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 33.3ms
# Speed: 3.7ms preprocess, 33.3ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 33.5ms
# Speed: 4.1ms preprocess, 33.5ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 33.3ms
# Speed: 4.6ms preprocess, 33.3ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 33.6ms
# Speed: 4.4ms preprocess, 33.6ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 33.5ms
# Speed: 4.1ms preprocess, 33.5ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 33.6ms
# Speed: 6.5ms preprocess, 33.6ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 34.1ms
# Speed: 3.9ms preprocess, 34.1ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 34.6ms
# Speed: 3.9ms preprocess, 34.6ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 34.7ms
# Speed: 4.2ms preprocess, 34.7ms inference, 20.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 34.9ms
# Speed: 3.9ms preprocess, 34.9ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 34.6ms
# Speed: 4.6ms preprocess, 34.6ms inference, 9.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 34.7ms
# Speed: 4.6ms preprocess, 34.7ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 34.8ms
# Speed: 4.1ms preprocess, 34.8ms inference, 10.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 4 cars, 34.4ms
# Speed: 3.9ms preprocess, 34.4ms inference, 10.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 34.5ms
# Speed: 3.7ms preprocess, 34.5ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 34.2ms
# Speed: 4.7ms preprocess, 34.2ms inference, 11.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 34.4ms
# Speed: 5.7ms preprocess, 34.4ms inference, 16.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 34.4ms
# Speed: 4.0ms preprocess, 34.4ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 2790/2832 - Quedan 42 frames
#
# 0: 384x640 1 person, 4 cars, 34.6ms
# Speed: 4.1ms preprocess, 34.6ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 34.3ms
# Speed: 3.6ms preprocess, 34.3ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 33.6ms
# Speed: 4.7ms preprocess, 33.6ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 33.6ms
# Speed: 3.8ms preprocess, 33.6ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 33.6ms
# Speed: 3.9ms preprocess, 33.6ms inference, 14.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 33.6ms
# Speed: 4.0ms preprocess, 33.6ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 40.3ms
# Speed: 5.0ms preprocess, 40.3ms inference, 21.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 32.9ms
# Speed: 4.0ms preprocess, 32.9ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 37.9ms
# Speed: 6.0ms preprocess, 37.9ms inference, 25.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 47.1ms
# Speed: 5.5ms preprocess, 47.1ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 33.1ms
# Speed: 4.9ms preprocess, 33.1ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 33.2ms
# Speed: 4.8ms preprocess, 33.2ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 33.4ms
# Speed: 5.6ms preprocess, 33.4ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 41.4ms
# Speed: 7.3ms preprocess, 41.4ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 33.4ms
# Speed: 4.8ms preprocess, 33.4ms inference, 10.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 35.0ms
# Speed: 4.7ms preprocess, 35.0ms inference, 11.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 35.2ms
# Speed: 4.3ms preprocess, 35.2ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 35.1ms
# Speed: 4.7ms preprocess, 35.1ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 35.3ms
# Speed: 4.7ms preprocess, 35.3ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 39.5ms
# Speed: 6.4ms preprocess, 39.5ms inference, 13.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 43.3ms
# Speed: 4.8ms preprocess, 43.3ms inference, 22.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 36.3ms
# Speed: 4.9ms preprocess, 36.3ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 37.8ms
# Speed: 8.3ms preprocess, 37.8ms inference, 14.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 52.8ms
# Speed: 4.6ms preprocess, 52.8ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 72.8ms
# Speed: 6.2ms preprocess, 72.8ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 72.6ms
# Speed: 6.6ms preprocess, 72.6ms inference, 16.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 69.7ms
# Speed: 5.3ms preprocess, 69.7ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 34.0ms
# Speed: 5.2ms preprocess, 34.0ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 34.1ms
# Speed: 5.0ms preprocess, 34.1ms inference, 10.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 34.6ms
# Speed: 4.5ms preprocess, 34.6ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
# Frame 2820/2832 - Quedan 12 frames
#
# 0: 384x640 1 person, 4 cars, 34.3ms
# Speed: 4.5ms preprocess, 34.3ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 34.0ms
# Speed: 4.7ms preprocess, 34.0ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 34.0ms
# Speed: 5.0ms preprocess, 34.0ms inference, 19.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 34.2ms
# Speed: 4.9ms preprocess, 34.2ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 33.9ms
# Speed: 4.3ms preprocess, 33.9ms inference, 22.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 39.4ms
# Speed: 8.5ms preprocess, 39.4ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 36.9ms
# Speed: 4.7ms preprocess, 36.9ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 35.9ms
# Speed: 4.3ms preprocess, 35.9ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 49.1ms
# Speed: 4.2ms preprocess, 49.1ms inference, 15.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 35.9ms
# Speed: 4.8ms preprocess, 35.9ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 35.7ms
# Speed: 4.7ms preprocess, 35.7ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 36.0ms
# Speed: 4.5ms preprocess, 36.0ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# ============================================================
# Proceso completado
# Objetos únicos detectados:
# bus: 2
# car: 182
# person: 39
# truck: 24
# motorcycle: 4
# Matrículas detectadas: 197
# ============================================================
